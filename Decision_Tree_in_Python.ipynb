# %% [markdown]
# ## Titanic Survival
#
# Given the survival dataset of Titanic passengers, can you predict who could have been survived?
#
# #### Data Dictionary
# Fileds:
# PassengerId
# survival:   Survival,0 = No, 1 = Yes
# pclass:  	Ticket class, 	1 = 1st, 2 = 2nd, 3 = 3rd
# Name
# sex:         Sex
# Age: 	    Age in years
# sibsp: 	    # of siblings / spouses aboard the Titanic
# parch: 	    # of parents / children aboard the Titanic
# ticket: 	    Ticket number
# fare: 	    Passenger fare
# cabin: 	    Cabin number
# embarked: 	Port of Embarkation 	C = Cherbourg, Q = Queenstown, S = Southampton

# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
print(df.shape)
print(df.info())
df.head()
# Out:
# (891, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Analyze and Clean Data
# * Name and Ticket number are not useful.
# * Sex, Cabin and Embarked fileds are not numberic. They need to be changed to numeric.
# * Cabin has missing data.

# %%
df = df.set_index('PassengerId')
df = df.drop(['Name','Ticket'],axis = 1)
df.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500   NaN
# 2                   1       1  female  38.0      1      0  71.2833   C85
# 3                   1       3  female  26.0      0      0   7.9250   NaN
# 4                   1       1  female  35.0      1      0  53.1000  C123
# 5                   0       3    male  35.0      0      0   8.0500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S

# %%
# Make sure all rows have a class.
# This shows that the classes are imbalanced
from collections import Counter
c = Counter(df['Survived'])
print(c)
# Out:
# Counter({0: 549, 1: 342})

# %%
# Let's see how much missing data we have

total = df.isnull().sum().sort_values(ascending=False)

percent_1 = df.isnull().sum()/df.isnull().count()*100

percent_2 = (round(percent_1, 1)).sort_values(ascending=False)

missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])

missing_data.head(10)
# Out:
#           Total     %
# Cabin       687  77.1
# Age         177  19.9
# Embarked      2   0.2
# Survived      0   0.0
# Pclass        0   0.0
# Sex           0   0.0
# SibSp         0   0.0
# Parch         0   0.0
# Fare          0   0.0

# %%
# Cabin has too much missing. Let's drop it.
df = df.drop(['Cabin'],axis=1)
df.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500        S
# 2                   1       1  female  38.0      1      0  71.2833        C
# 3                   1       3  female  26.0      0      0   7.9250        S
# 4                   1       1  female  35.0      1      0  53.1000        S
# 5                   0       3    male  35.0      0      0   8.0500        S

# %%
import numpy as np

age_mean = df["Age"].mean()
age_std = df["Age"].std()
is_null = df["Age"].isnull().sum()

# create a list of random numbers between the mean, std and is_null
rand_age = np.random.randint(age_mean - age_std, age_mean + age_std, size = is_null)

# fill null values in Age column with random values generated
age_slice = df["Age"].copy()
age_slice[np.isnan(age_slice)] = rand_age
df["Age"] = age_slice

print('number of null age values:',df["Age"].isnull().sum())
# Out:
# number of null age values: 0

# %%
# let's see the values that we have in Sex, Cabin and Embarked.
from collections import Counter
sex_count = Counter(df['Sex'])
Embarked_count = Counter(df['Embarked'])
print('sex_count:',sex_count)
print('-----------------')
print('-----------------')
print('Embarked_count:',Embarked_count)
# Out:
# sex_count: Counter({'male': 577, 'female': 314})
# -----------------
# -----------------
# Embarked_count: Counter({'S': 644, 'C': 168, 'Q': 77, nan: 2})

# %%
# Let's replace values with their indecies in the counters
# nans are also replaced by the relative index
# We can drop the original fields.

df['sex_numeric'] = df['Sex'].apply(lambda x: list(sex_count.keys()).index(x))

df['Embarked_numeric'] = df['Embarked'].apply(
    lambda x: list(Embarked_count.keys()).index(x))

df = df.drop(['Sex','Embarked'],axis = 1)

df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  sex_numeric  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500            0
# 2                   1       1  38.0      1      0  71.2833            1
# 3                   1       3  26.0      0      0   7.9250            1
# 4                   1       1  35.0      1      0  53.1000            1
# 5                   0       3  35.0      0      0   8.0500            0
#
#              Embarked_numeric
# PassengerId
# 1                           0
# 2                           1
# 3                           0
# 4                           0
# 5                           0

# %% [markdown]
# ## Machine Learning Starts Here!
# Now that the data is cleaned, we are ready to do machine learning.

# %%
# First, we seperate input and output data.
df_y = pd.DataFrame(df['Survived'])
df_x = df[['Pclass','Age','SibSp','Parch','Fare','sex_numeric',
           'Embarked_numeric']]

# %%
# Keep some data for out of sample testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df_x,df_y, test_size=0.2)

# %%
X_train.head()
# Out:
#              Pclass   Age  SibSp  Parch      Fare  sex_numeric  \
# PassengerId
# 391               1  36.0      1      2  120.0000            0
# 669               3  43.0      0      0    8.0500            0
# 350               3  42.0      0      0    8.6625            0
# 709               1  22.0      0      0  151.5500            1
# 449               3   5.0      2      1   19.2583            1
#
#              Embarked_numeric
# PassengerId
# 391                         0
# 669                         0
# 350                         0
# 709                         0
# 449                         1

# %%
y_train.head()
# Out:
#              Survived
# PassengerId
# 391                 1
# 669                 0
# 350                 0
# 709                 1
# 449                 1

# %%
# Let's train our decision tree
from sklearn import tree

clf = tree.DecisionTreeClassifier(random_state=100256)

clf = clf.fit(X_train,y_train)

# %%
tree.plot_tree(clf)
# Out:
# [Text(197.0956087360595, 210.645, 'X[5] <= 0.5\ngini = 0.474\nsamples = 712\nvalue = [437, 275]'),
#  Text(126.87239776951674, 197.055, 'X[4] <= 26.269\ngini = 0.311\nsamples = 463\nvalue = [374, 89]'),
#  Text(56.62973977695168, 183.465, 'X[1] <= 13.5\ngini = 0.215\nsamples = 334\nvalue = [293, 41]'),
#  Text(12.446096654275093, 169.875, 'X[2] <= 2.0\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(9.956877323420075, 156.285, 'X[3] <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(7.467657992565057, 142.695, 'X[2] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(4.978438661710038, 129.10500000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(9.956877323420075, 129.10500000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(12.446096654275093, 142.695, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(14.935315985130114, 156.285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(100.81338289962827, 169.875, 'X[1] <= 34.25\ngini = 0.169\nsamples = 321\nvalue = [291, 30]'),
#  Text(63.47509293680298, 156.285, 'X[1] <= 28.75\ngini = 0.197\nsamples = 226\nvalue = [201, 25]'),
#  Text(31.115241635687735, 142.695, 'X[4] <= 7.013\ngini = 0.159\nsamples = 161\nvalue = [147, 14]'),
#  Text(14.935315985130114, 129.10500000000002, 'X[1] <= 22.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(12.446096654275093, 115.515, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(17.424535315985132, 115.515, 'X[0] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(14.935315985130114, 101.925, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(19.91375464684015, 101.925, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text
000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(94.59033457249072, 101.925, 'X[4] <= 25.0\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(89.61189591078067, 88.33500000000001, 'X[1] <= 30.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(87.12267657992565, 74.745, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(92.1011152416357, 74.745, 'X[1] <= 31.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(89.61189591078067, 61.155, 'X[4] <= 11.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(87.12267657992565, 47.565, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(92.1011152416357, 47.565, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(94.59033457249072, 61.155, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(99.56877323420075, 88.33500000000001, 'X[3] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(97.07955390334573, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(102.05799256505577, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(109.52565055762082, 115.515, 'X[4] <= 12.637\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(107.03643122676581, 101.925, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(112.01486988847584, 101.925, 'X[6] <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(109.52565055762082, 88.33500000000001, 'X[2] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(107.03643122676581, 74.745, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(112.01486988847584, 74.745, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(114.50408921933087, 88.33500000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(138.15167286245355, 156.285, 'X[1] <= 61.5\ngini = 0.1\nsamples = 95\nvalue = [90, 5]'),
#  Text(133.1732342007435, 142.695, 'X[4] <= 13.25\ngini = 0.085\nsamples = 90\nvalue = [86, 4]'),
#  Text(130.6840148698885, 129.10500000000002, 'X[4] <= 12.938\ngini = 0.114\nsamples = 66\nvalue = [62, 4]'),
#  Text(121.97174721189592, 115.515, 'X[4] <= 7.227\ngini = 0.094\nsamples = 61\nvalue = [58, 3]'),
#  Text(119.48252788104091, 101.925, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(124.46096654275094, 101.925, 'X[4] <= 7.24\ngini = 0.13\nsamples = 43\nvalue = [40, 3]'),
#  Text(119.48252788104091, 88.33500000000001, 'X[1] <= 37.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(116.99330855018589, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(121.97174721189592, 74.745, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(129.43940520446097, 88.33500000000001, 'X[1] <= 38.5\ngini = 0.095\nsamples = 40\nvalue = [38, 2]'),
#  Text(126.95018587360596, 74.745, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(131.928624535316, 74.745, 'X[1] <= 39.5\ngini = 0.147\nsamples = 25\nvalue = [23, 2]'),
#  Text(126.95018587360596, 61.155, 'X[4] <= 7.85\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(124.46096654275094, 47.565, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(129.43940520446097, 47.565, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(136.90706319702602, 61.155, 'X[1] <= 44.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(134.417843866171, 47.565, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(139.39628252788106, 47.565, 'X[1] <= 46.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(136.90706319702602, 33.974999999999994, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(141.88550185873606, 33.974999999999994, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(139.39628252788106, 115.515, 'X[1] <= 45.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(136.90706319702602, 101.925, 'X[1] <= 39.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(134.417843866171, 88.33500000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(139.39628252788106, 88.33500000000001, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(141.88550185873606, 101.925, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(135.66245353159852, 129.10500000000002, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(143.13011152416357, 142.695, 'X[1] <= 63.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(140.64089219330856, 129.10500000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(145.6193308550186, 129.10500000000002, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(197.1150557620818, 183.465, 'X[2] <= 1.5\ngini = 0.467\nsamples = 129\nvalue = [81, 48]'),
#  Text(178.9126394052045, 169.875, 'X[1] <= 42.5\ngini = 0.489\nsamples = 108\nvalue = [62, 46]'),
#  Text(157.44312267657995, 156.285, 'X[1] <= 15.5\ngini = 0.496\nsamples = 70\nvalue = [32, 38]'),
#  Text(154.9539033457249, 142.695, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(159.93234200743495, 142.695, 'X[4] <= 26.775\ngini = 0.5\nsamples = 63\nvalue = [32, 31]'),
#  Text(150.59776951672865, 129.10500000000002, 'X[1] <= 37.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(148.1085501858736, 115.515, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(153.08698884758365, 115.515, 'X[1] <= 40.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(150.59776951672865, 101.925, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(155.57620817843866, 101.925, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(169.2669144981413, 129.10500000000002, 'X[4] <= 52.277\ngini = 0.489\nsamples = 54\nvalue = [31, 23]'),
#  Text(163.04386617100374, 115.515, 'X[2] <= 0.5\ngini = 0.391\nsamples = 30\nvalue = [22, 8]'),
#  Text(160.5546468401487, 101.925, 'X[4] <= 37.812\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text
 156.285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(237.72044609665429, 169.875, 'X[4] <= 28.856\ngini = 0.083\nsamples = 138\nvalue = [6, 132]'),
#  Text(232.74200743494427, 156.285, 'X[4] <= 28.231\ngini = 0.16\nsamples = 57\nvalue = [5, 52]'),
#  Text(230.25278810408923, 142.695, 'X[1] <= 37.0\ngini = 0.133\nsamples = 56\nvalue = [4, 52]'),
#  Text(225.2743494423792, 129.10500000000002, 'X[1] <= 27.5\ngini = 0.089\nsamples = 43\nvalue = [2, 41]'),
#  Text(222.78513011152418, 115.515, 'X[1] <= 23.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(220.29591078066917, 101.925, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(225.2743494423792, 101.925, 'X[4] <= 23.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(222.78513011152418, 88.33500000000001, 'X[4] <= 17.75\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(220.29591078066917, 74.745, 'X[4] <= 13.429\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(217.80669144981414, 61.155, 'X[4] <= 11.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(215.31747211895913, 47.565, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(220.29591078066917, 47.565, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(222.78513011152418, 61.155, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(225.2743494423792, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(227.76356877323423, 88.33500000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(227.76356877323423, 115.515, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(235.23122676579928, 129.10500000000002, 'X[1] <= 39.0\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(232.74200743494427, 115.515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(237.72044609665429, 115.515, 'X[2] <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(235.23122676579928, 101.925, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(240.20966542750932, 101.925, 'X[1] <= 43.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(237.72044609665429, 88.33500000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(242.69888475836433, 88.33500000000001, 'X[3] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(240.20966542750932, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(245.18810408921934, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(235.23122676579928, 142.695, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(242.69888475836433, 156.285, 'X[3] <= 1.5\ngini = 0.024\nsamples = 81\nvalue = [1, 80]'),
#  Text(240.20966542750932, 142.695, 'gini = 0.0\nsamples = 69\nvalue = [0, 69]'),
#  Text(245.18810408921934, 142.695, 'X[4] <= 135.775\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(242.69888475836433, 129.10500000000002, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(247.67732342007437, 129.10500000000002, 'X[4] <= 158.208\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(245.18810408921934, 115.515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(250.16654275092938, 115.515, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(303.14024163568774, 183.465, 'X[4] <= 23.7\ngini = 0.5\nsamples = 109\nvalue = [56, 53]'),
#  Text(281.43736059479556, 169.875, 'X[4] <= 7.888\ngini = 0.487\nsamples = 86\nvalue = [36, 50]'),
#  Text(257.63420074349443, 156.285, 'X[3] <= 1.0\ngini = 0.366\nsamples = 29\nvalue = [7, 22]'),
#  Text(255.14498141263942, 142.695, 'X[4] <= 6.987\ngini = 0.337\nsamples = 28\nvalue = [6, 22]'),
#  Text(252.65576208178442, 129.10500000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(257.63420074349443, 129.10500000000002, 'X[4] <= 7.59\ngini = 0.302\nsamples = 27\nvalue = [5, 22]'),
#  Text(255.14498141263942, 115.515, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(260.12342007434944, 115.515, 'X[4] <= 7.64\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(257.63420074349443, 101.925, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(262.6126394052045, 101.925, 'X[1] <= 32.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(260.12342007434944, 88.33500000000001, 'X[1] <= 30.25\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(257.63420074349443, 74.745, 'X[1] <= 21.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(255.14498141263942, 61.155, 'X[1] <= 17.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(252.65576208178442, 47.565, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(257.63420074349443, 47.565, 'X[4] <= 7.744\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(255.14498141263942, 33.974999999999994, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(260.12342007434944, 33.974999999999994, 'X[4] <= 7.815\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(257.63420074349443, 20.38499999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(262.6126394052045, 20.38499999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(260.12342007434944, 61.155, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(262.6126394052045, 74.745, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(265.1018587360595, 88.33500000000001, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(260.12342007434944, 142.695, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(305.2405204460967, 156.285, 'X[4] <= 15.373\ngini = 0.5\nsamples = 57\nvalue = [29, 28]'),
#  Text(293.10557620817843, 142.695, 'X[2] <= 0.5\ngini = 0.475\nsamples = 36\nvalue = [22, 14]'),
#  Text(283.7710037174721, 129.10500000000002, 'X[1] <= 24.5\ngini = 0.499\nsamples = 25\nvalue = [13, 12]'),
#  Text(277.5479553903346, 115.515, 'X[1] <= 16.0\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(272.56951672862454, 101.925, 'X[4] <= 11.375\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(270.0802973977695, 88.33500000000001, 'X[4] <= 8.083\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(267.5910780669145, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(272.56951672862454, 74.745, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(275.0587360594796, 88.33500000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(282.5263940520446, 101.925, 'X[4] <= 9.84\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(280.0371747211896, 88.33500000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(285.01561338289963, 88.33500000000001, 'X[4] <= 10.179\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(282.5263940520446, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(287.5048327137547, 74.745, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(289.9940520446097, 115.515, 'X[1] <= 27.5\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(287.5048327137547, 101.925, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(292.4832713754647, 101.925, 'X[4] <= 8.673\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(289.9940520446097, 88.33500000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(294.9724907063197, 88.33500000000001, 'X[1] <= 33.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(292.4832713754647, 74.745, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(297.4617100371747, 74.745, 'X[1] <= 50.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(294.9724907063197, 61.155, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(299.9509293680298, 61.155, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(302.4401486988848, 129.10500000000002, 'X[1] <= 18.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(299.9509293680298, 115.515, 'X[1] <= 14.75\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(297.4617100371747, 101.925, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(302.4401486988848, 101.925, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(304.9293680297398, 115.515, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(317.3754646840149, 142.695, 'X[4] <= 19.735\ngini = 0.444\nsamples = 21\nvalue = [7, 14]'),
#  Text(312.3970260223049, 129.10500000000002, 'X[1] <= 17.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(309.9078066914498, 115.515, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(314.8862453531599, 115.515, 'X[3] <= 1.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(312.3970260223049, 101.925, 'X[4] <= 17.7\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(309.9078066914498, 88.33500000000001, 'X[3] <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(307.4185873605948, 74.745, 'X[4] <= 15.975\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(304.9293680297398, 61.155, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(309.9078066914498, 61.155, 'X[1] <= 28.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(307.4185873605948, 47.565, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(312.3970260223049, 47.565, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(312.3970260223049, 74.745, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(314.8862453531599, 88.33500000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(317.3754646840149, 101.925, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(322.3539033457249, 129.10500000000002, 'X[1] <= 32.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(319.8646840148699, 115.515, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(324.8431226765799, 115.515, 'X[4] <= 20.231\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(322.3539033457249, 101.925, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(327.332342007435, 101.925, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(324.8431226765799, 169.875, 'X[3] <= 0.5\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(322.3539033457249, 156.285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(327.332342007435, 156.285, 'X[4] <= 31.331\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(324.8431226765799, 142.695, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(329.82156133829, 142.695, 'X[4] <= 32.881\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(327.332342007435, 129.10500000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(332.310780669145, 129.10500000000002, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]')]

# %%
# Now evaluate the model
from sklearn.metrics import accuracy_score,confusion_matrix

y_train_pred = clf.predict(X_train)
train_acc = accuracy_score(y_train,y_train_pred)
print('Train Accuracy:',round(train_acc * 100,2))

y_pred = clf.predict(X_test)
acc = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)

print('Accuracy:',round(acc*100,2))
print('Confusion Matrix:')
print(cm)
# Out:
# Train Accuracy: 99.02
# Accuracy: 77.09
# Confusion Matrix:
# [[91 21]
#  [20 47]]

# %%
X_train.head()
# Out:
#              Pclass   Age  SibSp  Parch      Fare  sex_numeric  \
# PassengerId
# 391               1  36.0      1      2  120.0000            0
# 669               3  43.0      0      0    8.0500            0
# 350               3  42.0      0      0    8.6625            0
# 709               1  22.0      0      0  151.5500            1
# 449               3   5.0      2      1   19.2583            1
#
#              Embarked_numeric
# PassengerId
# 391                         0
# 669                         0
# 350                         0
# 709                         0
# 449                         1

# %%
y_train.head()
# Out:
#              Survived
# PassengerId
# 391                 1
# 669                 0
# 350                 0
# 709                 1
# 449                 1

# %%
from sklearn.model_selection import GridSearchCV

# This is not good. Let's see if it can be improved using cross validation.
param_dict = {'criterion':['gini','entropy'],
              'max_depth':range(1,10), # How deep the tree can go
              'min_samples_split':range(1,10), # min number of samples needed to split
              'min_samples_leaf':range(1,5)} # min number of samples should reach a leaf

# What is the mode to do cross validation
clf_CV = tree.DecisionTreeClassifier()
# create the grid search
grid = GridSearchCV(clf_CV,param_grid=param_dict,cv=10,verbose=1,n_jobs=-1)
# search the grid
grid.fit(X_train,y_train)

# Get the best model that we could find
best_clf = grid.best_estimator_
# Out:
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
# /Users/raha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan 0.78663928 0.78663928 0.78663928 0.78663928 0.78663928
#  0.78663928 0.78663928 0.78663928        nan 0.78663928 0.78663928
#  0.78663928 0.78663928 0.78663928 0.78663928 0.78663928 0.78663928
#         nan 0.78663928 0.78663928 0.78663928 0.78663928 0.78663928
#  0.78663928 0.78663928 0.78663928        nan 0.78663928 0.78663928
#  0.78663928 0.78663928 0.78663928 0.78663928 0.78663928 0.78663928
#         nan 0.78243349 0.78243349 0.78243349 0.78243349 0.78243349
#  0.78243349 0.78243349 0.78243349        nan 0.78243349 0.78243349
#  0.78243349 0.78243349 0.78243349 0.78243349 0.78243349 0.78243349
#         nan 0.78243349 0.78243349 0.78243349 0.78243349 0.78243349
#  0.78243349 0.78243349 0.78243349        nan 0.78243349 0.78243349
#  0.78243349 0.78243349 0.78243349 0.78243349 0.78243349 0.78243349
#         nan 0.80483177 0.80483177 0.80483177 0.80483177 0.80483177
#  0.80483177 0.80483177 0.80483177        nan 0.80483177 0.80483177
#  0.80483177 0.80483177 0.80483177 0.80483177 0.80483177 0.80483177
#         nan 0.80764867 0.80764867 0.80764867 0.80764867 0.80764867
#  0.80764867 0.80764867 0.80764867        nan 0.80483177 0.80483177
#  0.80483177 0.80483177 0.80483177 0.80483177 0.80483177 0.80483177
#         nan 0.78933881 0.79356416 0.79356416 0.79215571 0.79215571
#  0.79215571 0.79356416 0.79356416        nan 0.79356416 0.79356416
#  0.79356416 0.79356416 0.79356416 0.79356416 0.79356416 0.79356416
#         nan 0.79638106 0.79638106 0.79638106 0.79638106 0.79638106
#  0.79638106 0.79638106 0.79638106        nan 0.78937793 0.78937793
#  0.78937793 0.78937793 0.78937793 0.78937793 0.78937793 0.78937793
#         nan 0.81175665 0.81318466 0.81457355 0.81177621 0.8131651
#  0.81175665 0.80897887 0.81320423        nan 0.815982   0.81459311
#  0.81459311 0.81459311 0.81459311 0.815982   0.81320423 0.81320423
#         nan 0.81739045 0.815982   0.81600156 0.81600156 0.815982
#  0.8187989  0.81742958 0.81742958        nan 0.80903756 0.80903756
#  0.80903756 0.80903756 0.80903756 0.80903756 0.80903756 0.80903756
#         nan 0.80046948 0.80187793 0.80465571 0.80326682 0.80326682
#  0.80465571 0.80187793 0.80469484        nan 0.80612285 0.8047144
#  0.80612285 0.80751174 0.80751174 0.80751174 0.80751174 0.80751174
#         nan 0.80612285 0.80612285 0.8075313  0.8075313  0.8075313
#  0.81032864 0.8103482  0.8103482         nan 0.79640063 0.79640063
#  0.79640063 0.79640063 0.79640063 0.79640063 0.79640063 0.79640063
#         nan 0.81173709 0.80749218 0.81451487 0.81451487 0.81171753
#  0.81592332 0.81032864 0.81173709        nan 0.81032864 0.81173709
#  0.81453443 0.81455399 0.81453443 0.81314554 0.81173709 0.81455399
#         nan 0.81737089 0.81735133 0.815982   0.81594288 0.8131651
#         nan 0.81739045 0.815982   0.81457355 0.81739045 0.815982
#  0.8187989  0.8187989  0.8187989         nan 0.80907668 0.80907668
#  0.80907668 0.80907668 0.80907668 0.80907668 0.80907668 0.80907668
#         nan 0.82022692 0.82163537 0.82304382 0.82445227 0.82445227
#  0.82445227 0.82445227 0.82586072        nan 0.82304382 0.82867762
#  0.82445227 0.82586072 0.82586072 0.82726917 0.82586072 0.82726917
#         nan 0.82165493 0.81883803 0.81883803 0.82024648 0.82024648
#  0.82165493 0.82306338 0.82447183        nan 0.81748826 0.81609937
#  0.81748826 0.81748826 0.81748826 0.81748826 0.81609937 0.81889671
#         nan 0.79356416 0.79497261 0.79497261 0.79356416 0.79497261
#  0.79356416 0.7963615  0.7935446         nan 0.79501174 0.79642019
#  0.79642019 0.79501174 0.79782864 0.79501174 0.79499218 0.79921753
#         nan 0.79219484 0.79219484 0.79219484 0.79501174 0.79219484
#  0.79219484 0.79358372 0.79921753        nan 0.79921753 0.79923709
#  0.79921753 0.80062598 0.79782864 0.80062598 0.80062598 0.80203443
#         nan 0.79771127 0.80052817 0.80193662 0.79769171 0.80052817
#  0.80050861 0.80048905 0.80332551        nan 0.80052817 0.80193662
#  0.79911972 0.80195618 0.80336463 0.80197574 0.80054773 0.80477308
#         nan 0.80336463 0.80336463 0.80195618 0.80618153 0.80477308
#  0.80618153 0.80052817 0.80475352        nan 0.79499218 0.79778951
#  0.79497261 0.80058685 0.79919797 0.79499218 0.79358372 0.79638106]
#   warnings.warn(

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 7,
#  'min_samples_leaf': 2,
#  'min_samples_split': 3}

# %%
# Let's reevaluate

y_train_pred = best_clf.predict(X_train)
train_acc = accuracy_score(y_train,y_train_pred)
print('Train Accuracy:',round(train_acc * 100,2))

y_pred = best_clf.predict(X_test)
acc = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)

print('Accuracy:',round(acc*100,2))
print('Confusion Matrix:')
print(cm)
# Out:
# Train Accuracy: 87.36
# Accuracy: 82.68
# Confusion Matrix:
# [[103   9]
#  [ 22  45]]

# %%
# For reference
c_test = Counter(y_test['Survived'])
print(c_test)
# Out:
# Counter({0: 112, 1: 67})

# %%
tree.plot_tree(best_clf)
# Out:
# [Text(161.296875, 203.85, 'X[5] <= 0.5\nentropy = 0.962\nsamples = 712\nvalue = [437, 275]'),
#  Text(89.62875, 176.67000000000002, 'X[4] <= 26.269\nentropy = 0.706\nsamples = 463\nvalue = [374, 89]'),
#  Text(39.7575, 149.49, 'X[1] <= 13.5\nentropy = 0.537\nsamples = 334\nvalue = [293, 41]'),
#  Text(11.16, 122.31, 'X[4] <= 18.769\nentropy = 0.619\nsamples = 13\nvalue = [2, 11]'),
#  Text(5.58, 95.13, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(16.740000000000002, 95.13, 'X[3] <= 1.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(11.16, 67.94999999999999, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(22.32, 67.94999999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(68.355, 122.31, 'X[1] <= 34.25\nentropy = 0.448\nsamples = 321\nvalue = [291, 30]'),
#  Text(47.43, 95.13, 'X[1] <= 28.75\nentropy = 0.502\nsamples = 226\nvalue = [201, 25]'),
#  Text(33.480000000000004, 67.94999999999999, 'X[6] <= 0.5\nentropy = 0.426\nsamples = 161\nvalue = [147, 14]'),
#  Text(22.32, 40.77000000000001, 'X[4] <= 8.135\nentropy = 0.359\nsamples = 132\nvalue = [123, 9]'),
#  Text(16.740000000000002, 13.590000000000003, 'entropy = 0.477\nsamples = 78\nvalue = [70, 8]'),
#  Text(27.9, 13.590000000000003, 'entropy = 0.133\nsamples = 54\nvalue = [53, 1]'),
#  Text(44.64, 40.77000000000001, 'X[4] <= 10.879\nentropy = 0.663\nsamples = 29\nvalue = [24, 5]'),
#  Text(39.06, 13.590000000000003, 'entropy = 0.426\nsamples = 23\nvalue = [21, 2]'),
#  Text(50.22, 13.590000000000003, 'entropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(61.38, 67.94999999999999, 'X[4] <= 7.744\nentropy = 0.656\nsamples = 65\nvalue = [54, 11]'),
#  Text(55.8, 40.77000000000001, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(66.96000000000001, 40.77000000000001, 'X[1] <= 32.5\nentropy = 0.701\nsamples = 58\nvalue = [47, 11]'),
#  Text(61.38, 13.590000000000003, 'entropy = 0.779\nsamples = 39\nvalue = [30, 9]'),
#  Text(72.54, 13.590000000000003, 'entropy = 0.485\nsamples = 19\nvalue = [17, 2]'),
#  Text(89.28, 95.13, 'X[4] <= 13.25\nentropy = 0.297\nsamples = 95\nvalue = [90, 5]'),
#  Text(83.7, 67.94999999999999, 'X[4] <= 7.227\nentropy = 0.367\nsamples = 71\nvalue = [66, 5]'),
#  Text(78.12, 40.77000000000001, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(89.28, 40.77000000000001, 'X[4] <= 7.24\nentropy = 0.451\nsamples = 53\nvalue = [48, 5]'),
#  Text(83.7, 13.590000000000003, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(94.86, 13.590000000000003, 'entropy = 0.402\nsamples = 50\nvalue = [46, 4]'),
#  Text(94.86, 67.94999999999999, 'entropy = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(139.5, 149.49, 'X[2] <= 2.5\nentropy = 0.952\nsamples = 129\nvalue = [81, 48]'),
#  Text(122.76, 122.31, 'X[1] <= 15.5\nentropy = 0.981\nsamples = 112\nvalue = [65, 47]'),
#  Text(117.18, 95.13, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(128.34, 95.13, 'X[1] <= 60.5\nentropy = 0.959\nsamples = 105\nvalue = [65, 40]'),
#  Text(122.76, 67.94999999999999, 'X[4] <= 26.775\nentropy = 0.98\nsamples = 96\nvalue = [56, 40]'),
#  Text(111.6, 40.77000000000001, 'X[1] <= 37.0\nentropy = 0.837\nsamples = 15\nvalue = [4, 11]'),
#  Text(106.02, 13.590000000000003, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(117.18, 13.590000000000003, 'entropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(133.92000000000002, 40.77000000000001, 'X[4] <= 29.1\nentropy = 0.941\nsamples = 81\nvalue = [52, 29]'),
#  Text(128.34, 13.590000000000003, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(139.5, 13.590000000000003, 'entropy = 0.969\nsamples = 73\nvalue = [44, 29]'),
#  Text(133.92000000000002, 67.94999999999999, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(156.24, 122.31, 'X[1] <= 3.5\nentropy = 0.323\nsamples = 17\nvalue = [16, 1]'),
#  Text(150.66, 95.13, 'X[4] <= 35.538\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(145.08, 67.94999999999999, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(156.24, 67.94999999999999, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(161.82, 95.13, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(232.965, 176.67000000000002, 'X[0] <= 2.5\nentropy = 0.816\nsamples = 249\nvalue = [63, 186]'),
#  Text(178.56, 149.49, 'X[1] <= 2.5\nentropy = 0.286\nsamples = 140\nvalue = [7, 133]'),
#  Text(172.98, 122.31, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(184.14000000000001, 122.31, 'X[4] <= 28.856\nentropy = 0.258\nsamples = 138\nvalue = [6, 132]'),
#  Text(172.98, 95.13, 'X[3] <= 0.5\nentropy = 0.429\nsamples = 57\nvalue = [5, 52]'),
#  Text(167.4, 67.94999999999999, 'X[4] <= 12.825\nentropy = 0.527\nsamples = 42\nvalue = [5, 37]'),
#  Text(161.82, 40.77000000000001, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(172.98, 40.77000000000001, 'X[1] <= 37.0\nentropy = 0.637\nsamples = 31\nvalue = [5, 26]'),
#  Text(167.4, 13.590000000000003, 'entropy = 0.439\nsamples = 22\nvalue = [2, 20]'),
#  Text(178.56, 13.590000000000003, 'entropy = 0.918\nsamples = 9\nvalue = [3, 6]'),
#  Text(178.56, 67.94999999999999, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(195.3, 95.13, 'X[3] <= 1.5\nentropy = 0.096\nsamples = 81\nvalue = [1, 80]'),
#  Text(189.72, 67.94999999999999, 'entropy = 0.0\nsamples = 69\nvalue = [0, 69]'),
#  Text(200.88, 67.94999999999999, 'X[4] <= 135.775\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]'),
#  Text(195.3, 40.77000000000001, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(206.46, 40.77000000000001, 'X[1] <= 24.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(200.88, 13.590000000000003, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(212.04, 13.590000000000003, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(287.37, 149.49, 'X[4] <= 24.808\nentropy = 0.999\nsamples = 109\nvalue = [56, 53]'),
#  Text(256.68, 122.31, 'X[4] <= 7.888\nentropy = 0.985\nsamples = 89\nvalue = [38, 51]'),
#  Text(228.78, 95.13, 'X[1] <= 17.5\nentropy = 0.797\nsamples = 29\nvalue = [7, 22]'),
#  Text(223.2, 67.94999999999999, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(234.36, 67.94999999999999, 'X[1] <= 32.5\nentropy = 0.887\nsamples = 23\nvalue = [7, 16]'),
#  Text(228.78, 40.77000000000001, 'X[1] <= 30.25\nentropy = 0.964\nsamples = 18\nvalue = [7, 11]'),
#  Text(223.2, 13.590000000000003, 'entropy = 0.896\nsamples = 16\nvalue = [5, 11]'),
#  Text(234.36, 13.590000000000003, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(239.94, 40.77000000000001, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(284.58, 95.13, 'X[4] <= 15.373\nentropy = 0.999\nsamples = 60\nvalue = [31, 29]'),
#  Text(262.26, 67.94999999999999, 'X[2] <= 0.5\nentropy = 0.964\nsamples = 36\nvalue = [22, 14]'),
#  Text(251.1, 40.77000000000001, 'X[1] <= 24.5\nentropy = 0.999\nsamples = 25\nvalue = [13, 12]'),
#  Text(245.52, 13.590000000000003, 'entropy = 0.918\nsamples = 12\nvalue = [8, 4]'),
#  Text(256.68, 13.590000000000003, 'entropy = 0.961\nsamples = 13\nvalue = [5, 8]'),
#  Text(273.42, 40.77000000000001, 'X[1] <= 18.5\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(267.84000000000003, 13.590000000000003, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(279.0, 13.590000000000003, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(306.9, 67.94999999999999, 'X[6] <= 0.5\nentropy = 0.954\nsamples = 24\nvalue = [9, 15]'),
#  Text(295.74, 40.77000000000001, 'X[4] <= 17.7\nentropy = 0.997\nsamples = 15\nvalue = [8, 7]'),
#  Text(290.16, 13.590000000000003, 'entropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(301.32, 13.590000000000003, 'entropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(318.06, 40.77000000000001, 'X[4] <= 17.379\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(312.48, 13.590000000000003, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(323.64, 13.590000000000003, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(318.06, 122.31, 'X[4] <= 31.331\nentropy = 0.469\nsamples = 20\nvalue = [18, 2]'),
#  Text(312.48, 95.13, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(323.64, 95.13, 'X[4] <= 32.881\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(318.06, 67.94999999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(329.22, 67.94999999999999, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]')]
